# %% [markdown]
# <a href="https://colab.research.google.com/github/mohd-faizy/Lib_Pandas/blob/master/01_Pandas_Titanic_DataSet_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
titanic_df = pd.read_excel('/content/drive/My Drive/Colab Notebooks/08_DataScience_Libraries /01_Pandas_Lib/titanic3.xls',
                           index_col=None, na_values=['NA'])

# %%
titanic_df.head()
# Out:
#    pclass  survived  ...   body                        home.dest
# 0       1         1  ...    NaN                     St Louis, MO
# 1       1         1  ...    NaN  Montreal, PQ / Chesterville, ON
# 2       1         0  ...    NaN  Montreal, PQ / Chesterville, ON
# 3       1         0  ...  135.0  Montreal, PQ / Chesterville, ON
# 4       1         0  ...    NaN  Montreal, PQ / Chesterville, ON
#
# [5 rows x 14 columns]

# %%
titanic_df.describe()
# Out:
#             pclass     survived  ...         fare        body
# count  1309.000000  1309.000000  ...  1308.000000  121.000000
# mean      2.294882     0.381971  ...    33.295479  160.809917
# std       0.837836     0.486055  ...    51.758668   97.696922
# min       1.000000     0.000000  ...     0.000000    1.000000
# 25%       2.000000     0.000000  ...     7.895800   72.000000
# 50%       3.000000     0.000000  ...    14.454200  155.000000
# 75%       3.000000     1.000000  ...    31.275000  256.000000
# max       3.000000     1.000000  ...   512.329200  328.000000
#
# [8 rows x 7 columns]

# %%
titanic_df.drop(['ticket', 'cabin', 'boat', 'body'], axis=1).head()
# Out:
#    pclass  survived  ... embarked                        home.dest
# 0       1         1  ...        S                     St Louis, MO
# 1       1         1  ...        S  Montreal, PQ / Chesterville, ON
# 2       1         0  ...        S  Montreal, PQ / Chesterville, ON
# 3       1         0  ...        S  Montreal, PQ / Chesterville, ON
# 4       1         0  ...        S  Montreal, PQ / Chesterville, ON
#
# [5 rows x 10 columns]

# %%
titanic_df.isnull()
# Out:
#       pclass  survived   name    sex  ...  embarked   boat   body  home.dest
# 0      False     False  False  False  ...     False  False   True      False
# 1      False     False  False  False  ...     False  False   True      False
# 2      False     False  False  False  ...     False   True   True      False
# 3      False     False  False  False  ...     False   True  False      False
# 4      False     False  False  False  ...     False   True   True      False
# ...      ...       ...    ...    ...  ...       ...    ...    ...        ...
# 1304   False     False  False  False  ...     False   True  False       True
# 1305   False     False  False  False  ...     False   True   True       True
# 1306   False     False  False  False  ...     False   True  False       True
# 1307   False     False  False  False  ...     False   True   True       True
# 1308   False     False  False  False  ...     False   True   True       True
#
# [1309 rows x 14 columns]

# %%
titanic_df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
pd.value_counts(titanic_df['survived']).plot.bar()

# %% [markdown]
# $0$ $\rightarrow$ $Died$
#
# $1$ $\rightarrow$ $Survived$

# %%
titanic_df['survived'].mean()
# Out:
# 0.3819709702062643

# %%
titanic_df.groupby(['sex']).mean()
# Out:
#           pclass  survived        age     sibsp     parch       fare       body
# sex
# female  2.154506  0.727468  28.687071  0.652361  0.633047  46.198097  166.62500
# male    2.372479  0.190985  30.585233  0.413998  0.247924  26.154601  160.39823

# %%
titanic_df.groupby(['sex', 'pclass']).mean()
# Out:
#                survived        age     sibsp     parch        fare        body
# sex    pclass
# female 1       0.965278  37.037594  0.555556  0.472222  109.412385         NaN
#        2       0.886792  27.499191  0.500000  0.650943   23.234827   52.000000
#        3       0.490741  22.185307  0.791667  0.731481   15.324250  183.000000
# male   1       0.340782  41.029250  0.340782  0.279330   69.888385  162.828571
#        2       0.146199  30.815401  0.327485  0.192982   19.904946  171.233333
#        3       0.152130  25.962273  0.470588  0.255578   12.415462  151.854167

# %%
titanic_df[titanic_df['age']<18].groupby(['sex', 'pclass']).mean()
# Out:
#                survived        age     sibsp     parch        fare   body
# sex    pclass
# female 1       0.875000  14.125000  0.500000  0.875000  104.083337    NaN
#        2       1.000000   8.273150  0.666667  1.166667   27.998844    NaN
#        3       0.543478   8.416667  1.456522  1.043478   18.284148  328.0
# male   1       0.857143   9.845243  0.571429  1.714286  129.752371    NaN
#        2       0.733333   6.222220  0.600000  0.933333   31.750280    NaN
#        3       0.233333   9.838888  1.966667  1.016667   21.677570   65.5
